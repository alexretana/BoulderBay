# %% [markdown]
# # Web Scrapping Analysis
#
# This notebook walks through the process of pulling, merging, and cleaning various datasets about climbing gyms around the US.

# %%
import pandas as pd
import numpy as np
import re
import requests
import json
from keys import GKEY
import numpy as np

# %%
#load the scrapped data from mountainProject(mP)
df = pd.read_json('data.json', orient='index')

df
# Out:
#                                                              locName    state  \
# Birmingham Boulders                              Birmingham Boulders  Alabama
# Campus Recreation Center                    Campus Recreation Center     Ohio
# Faucett Brothers Activity Center    Faucett Brothers Activity Center  Alabama
# First Avenue Rocks                                First Avenue Rocks  Alabama
# Fortenberry-Colton Fitness Center  Fortenberry-Colton Fitness Center  Alabama
# ...                                                              ...      ...
# Elemental Training Center                  Elemental Training Center  Wyoming
# Fall Hall                                                  Fall Hall  Wyoming
# Gottsche Glyphs                                      Gottsche Glyphs  Wyoming
# Pinedale Aquatic Center                      Pinedale Aquatic Center  Wyoming
# The Rock                                                    The Rock  Wyoming
#
#                                                                             img_list  \
# Birmingham Boulders                [https://cdn2.apstatic.com/photos/climb/119942...
# Campus Recreation Center                                                          []
# Faucett Brothers Activity Center                                                  []
# First Avenue Rocks                                                                []
# Fortenberry-Colton Fitness Center                                                 []
# ...                                                                              ...
# Elemental Training Center                                                         []
# Fall Hall                                                                         []
# Gottsche Glyphs                                                                   []
# Pinedale Aquatic Center            [https://cdn2.apstatic.com/photos/climb/107748...
# The Rock                                                                          []
#
#                                                                             gym_info
# Birmingham Boulders                [www.boulderingauthority.com,  136 INDUSTRIAL ...
# Campus Recreation Center           [www.uc.edu,  University of Cincinnati, 2820 B...
# Faucett Brothers Activity Center   [www.tcpara.org,  13040 Eugenia Faucett Drive ...
# First Avenue Rocks                 [firstaverocks.com,  2417 1st Avenue South, Bi...
# Fortenberry-Colton Fitness Center  [www.ftruckermwr.com,  Bldg. 5900 on the corne...
# ...                                                                              ...
# Elemental Training Center          [lmntl.net,  205 Lincoln St, Lander, Wyoming 8...
# Fall Hall                                           [ F.E.Warren AFB, Cheyenne, WY ]
# Gottsche Glyphs                    [gottsche.org,  148 E. Arapahoe, Thermopolis, ...
# Pinedale Aquatic Center            [www.pinedaleaquatic.com,  535 N. Tyler Ave., ...
# The Rock                           [www.rswy.net,  Rock Springs Civic Center, 410...
#
# [938 rows x 4 columns]

# %%
#list how many picutures were on mP
df['NumberOfImages'] = df.img_list.map(len)

# %%
#make data more pandas friendly

def getFirstItem(gym_info: list):
    try:
        return gym_info[0]
    except:
        return ""

def getSecondItem(gym_info: list):
    try:
        return gym_info[1]
    except:
        return ""

df['gymURL'] = df['gym_info'].map(getFirstItem)
df['gym_address'] = df['gym_info'].map(getSecondItem)

del df['gym_info']

# %%
df["google_Place_ID"] = ""
df["locLat"] = ""
df["locLong"] = ""
df["business_status"] = ""
df["google_photoReferences"] = ""
df["googleRating"] = ""
df["numUsersRated"] = ""
df["typeList"] = ""

# %%
#grab non-nested values with try-except
def tryToGet(searchResults, resultKey: str, isList: bool = False):
    try:
        return searchResults[resultKey]
    except:
        if not isList:
            return ""
        else:
            return []

# %%
df[df['state'] == 'Delaware']
# Out:
#                                                                      locName  \
# Jewish Community Center Climbing Wall  Jewish Community Center Climbing Wall
# RISE Fitness + Adventure                            RISE Fitness + Adventure
# The Delaware Rock Gym                                  The Delaware Rock Gym
# University of Delaware Climbing Wall    University of Delaware Climbing Wall
#
#                                           state  \
# Jewish Community Center Climbing Wall  Delaware
# RISE Fitness + Adventure               Delaware
# The Delaware Rock Gym                  Delaware
# University of Delaware Climbing Wall   Delaware
#
#                                                                                 img_list  \
# Jewish Community Center Climbing Wall                                                 []
# RISE Fitness + Adventure                                                              []
# The Delaware Rock Gym                                                                 []
# University of Delaware Climbing Wall   [https://cdn2.apstatic.com/photos/climb/112034...
#
#                                        NumberOfImages             gymURL  \
# Jewish Community Center Climbing Wall               0  www.siegeljcc.org
# RISE Fitness + Adventure                            0
# The Delaware Rock Gym                               0  www.derockgym.com
# University of Delaware Climbing Wall                2       www.udel.edu
#
#                                                                              gym_address  \
# Jewish Community Center Climbing Wall   101 Garden of Eden Road, Wilmington, Delaware...
# RISE Fitness + Adventure                     35770 Airport Rd, Rehoboth Beach, DE 19971
# The Delaware Rock Gym                              520 Carson Dr., Bear, Delaware 19701
# University of Delaware Climbing Wall    Carpenter Center, North College Street, Newar...
#
#                                       google_Place_ID locLat locLong  \
# Jewish Community Center Climbing Wall
# RISE Fitness + Adventure
# The Delaware Rock Gym
# University of Delaware Climbing Wall
#
#                                       business_status google_photoReferences  \
# Jewish Community Center Climbing Wall
# RISE Fitness + Adventure
# The Delaware Rock Gym
# University of Delaware Climbing Wall
#
#                                       googleRating numUsersRated typeList
# Jewish Community Center Climbing Wall
# RISE Fitness + Adventure
# The Delaware Rock Gym
# University of Delaware Climbing Wall

# %%
# Out:
# Index(['locName', 'state', 'img_list', 'NumberOfImages', 'gymURL',
#        'gym_address', 'google_Place_ID', 'locLat', 'locLong',
#        'business_status', 'google_photoReferences', 'googleRating',
#        'numUsersRated', 'typeList'],
#       dtype='object')

# %%
df.img_list.apply("".join).str.len().max()
# Out:
# 1152

# %%
#specify the url endpoint to send the request to
placeTextSearchURL = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
fields = [
        "place_id",
        "business_status",
        "rating",
        "types",
        "user_ratings_total",
        "name",
        "geometry",
        'photos'
    ]

for idx, row in df.iterrows():

    #assign address to variable, and create params dict
    address = row['locName'].strip('…') + " " + row['gym_address']
    
    params = {
                "key": GKEY,
                "query": address,
                'fields':fields
             }
    #get request to location text search api endpoint
    searchResults = requests.get(placeTextSearchURL, params=params)
    
    #conv to dict for easy extract
    searchResults = searchResults.json()
    
    #if results are empty, attmept a second search with just name
    if not searchResults["results"]:
        params.update({'query': row['locName'].strip('…')})
        searchResults = requests.get(placeTextSearchURL, params=params).json()
    
    if searchResults["results"]:
        searchResults = searchResults["results"][0]

    # extract non-nested value
    df.loc[idx,"google_Place_ID"] = tryToGet(searchResults,  "place_id")
    df.loc[idx,"business_status"] = tryToGet(searchResults,  "business_status")
    df.loc[idx,"googleRating"] = tryToGet(searchResults,"rating")
    df.at[idx,"typeList"] = tryToGet(searchResults, "types", True)
    df.loc[idx,"numUsersRated"] = tryToGet(searchResults, "user_ratings_total")
    
    #Try and update cleaner name
    try:
        df.loc[idx,"locName"] = searchResults["name"]
    except:
        pass
    
    #manual try blocks for nested values
    try:
        df.loc[idx,"locLat"] = searchResults["geometry"]["location"]["lat"]
        df.loc[idx,"locLong"] = searchResults["geometry"]["location"]["lat"]
    except:
        df.loc[idx,"locLat"] = np.nan
        df.loc[idx,"locLong"] = np.nan
        
    #
    try:
        photoReferenceList = []
        for photo in searchResults['photos']:
            photoReferenceList.append(photo["photo_reference"])
        df.at[idx,"google_photoReferences"] = photoReferenceList
    except:
        df.at[idx,"google_photoReferences"] = []

# %%
df
# Out:
#                                                                                   locName  \
# Campus Recreation Center                                            UAB Campus Recreation
# Fortenberry-Colton Fitness Center              Fortenberry-Colton Physical Fitness Center
# University of South Alabama - Student…                              307 N University Blvd
# High Point Climbing - Birmingham             High Point Climbing and Fitness - Birmingham
# Birmingham Boulders                                                   Birmingham Boulders
# Gadrock                                                                           Gadrock
# First Avenue Rocks                                                     First Avenue Rocks
# High Point Climbing - Huntsville             High Point Climbing and Fitness - Huntsville
# Auburn University Recreation and Well…  Auburn University Campus Recreation and Wellne...
# Faucett Brothers Activity Center                         Faucett Brothers Activity Center
# University of Alabama                                           Student Recreation Center
# YMCA Camp Cosby Alpine Tower                                              YMCA Camp Cosby
#
#                                                                                  img_list  \
# Campus Recreation Center                                                               []
# Fortenberry-Colton Fitness Center                                                      []
# University of South Alabama - Student…                                                 []
# High Point Climbing - Birmingham                                                       []
# Birmingham Boulders                     [https://cdn2.apstatic.com/photos/climb/119942...
# Gadrock                                                                                []
# First Avenue Rocks                                                                     []
# High Point Climbing - Huntsville        [https://cdn2.apstatic.com/photos/climb/118309...
# Auburn University Recreation and Well…                                                 []
# Faucett Brothers Activity Center                                                       []
# University of Alabama                                                                  []
# YMCA Camp Cosby Alpine Tower                                                           []
#
#                                                                                     gInfo  \
# Campus Recreation Center                {'geoLoc': [26.08135, -80.23653019999999], 'ra...
# Fortenberry-Colton Fitness Center       {'geoLoc': [31.3242639, -85.7180348], 'rating'...
# University of South Alabama - Student…  {'geoLoc': [30.6959406, -88.184236], 'rating':...
# High Point Climbing - Birmingham        {'geoLoc': [33.4206544, -86.6982553], 'rating'...
# Birmingham Boulders                     {'geoLoc': [33.4517437, -86.8511012], 'rating'...
# Gadrock                                 {'geoLoc': [33.9865983, -86.0056007], 'rating'...
# First Avenue Rocks                      {'geoLoc': [33.5146648, -86.7975348], 'rating'...
# High Point Climbing - Huntsville        {'geoLoc': [34.73785, -86.66708129999999], 'ra...
# Auburn University Recreation and Well…  {'geoLoc': [32.6012386, -85.4929846], 'rating'...
# Faucett Brothers Activity Center        {'geoLoc': [33.2868784, -87.6325483], 'rating'...
# University of Alabama                   {'geoLoc': [33.2140233, -87.5391418], 'rating'...
# YMCA Camp Cosby Alpine Tower            {'geoLoc': [33.44290489999999, -86.2779448], '...
#
#                                         NumberOfImages  \
# Campus Recreation Center                             0
# Fortenberry-Colton Fitness Center                    0
# University of South Alabama - Student…               0
# High Point Climbing - Birmingham                     0
# Birmingham Boulders                                  2
# Gadrock                                              0
# First Avenue Rocks                                   0
# High Point Climbing - Huntsville                     2
# Auburn University Recreation and Well…               0
# Faucett Brothers Activity Center                     0
# University of Alabama                                0
# YMCA Camp Cosby Alpine Tower                         0
#
#                                                              gymURL  \
# Campus Recreation Center                     studentaffairs.uab.edu
# Fortenberry-Colton Fitness Center               www.ftruckermwr.com
# University of South Alabama - Student…         www.southalabama.edu
# High Point Climbing - Birmingham              highpointclimbing.com
# Birmingham Boulders                     www.boulderingauthority.com
# Gadrock                                        www.climbgadrock.com
# First Avenue Rocks                                firstaverocks.com
# High Point Climbing - Huntsville              highpointclimbing.com
# Auburn University Recreation and Well…
# Faucett Brothers Activity Center                     www.tcpara.org
# University of Alabama                                   urec.ua.edu
# YMCA Camp Cosby Alpine Tower                      www.campcosby.org
#
#                                                                               gym_address  \
# Campus Recreation Center                 University of Alabama at Birmingham, 1501 Uni...
# Fortenberry-Colton Fitness Center        Bldg. 5900 on the corner of Skychief Street a...
# University of South Alabama - Student…   307 N University Blvd, Mobile, Alabama 36688-...
# High Point Climbing - Birmingham                       4766 US-280, Birmingham, AL 35242
# Birmingham Boulders                            136 INDUSTRIAL DRIVE BIRMINGHAM, AL 35211
# Gadrock                                  1403 Rainbow Drive Gadsden AL United States 3...
# First Avenue Rocks                       2417 1st Avenue South, Birmingham, Alabama 35...
# High Point Climbing - Huntsville         1020 Nunnahsae Park Dr. NW (4.43 mi) Huntsvil...
# Auburn University Recreation and Well…                  601 Heisman Dr, Auburn, AL 36849
# Faucett Brothers Activity Center         13040 Eugenia Faucett Drive Northport, AL 35473
# University of Alabama                        401 5th Ave East, Tuscaloosa, Alabama 35487
# YMCA Camp Cosby Alpine Tower             2290 Paul Bear Bryant Rd, Alpine, Alabama 35014
#
#                                                     google_Place_ID  \
# Campus Recreation Center                ChIJR93YI-kbiYgRvn3bM5fi5Bo
# Fortenberry-Colton Fitness Center       ChIJgbAAIFdkkogRdo8uPDRqM7U
# University of South Alabama - Student…  ChIJNf7vQamym4gRkPQKC3B5dv8
# High Point Climbing - Birmingham        ChIJdaFwuksWiYgRLNOnRSAvVAw
# Birmingham Boulders                     ChIJcWRT3-QeiYgR3v4dEd-ZWh8
# Gadrock                                 ChIJbe-sgFo5iogRiilt7YFURhs
# First Avenue Rocks                      ChIJccr7oL4biYgRIKx0BFFwVmQ
# High Point Climbing - Huntsville        ChIJf9WVenppYogR7zJB9wbuYPE
# Auburn University Recreation and Well…  ChIJ_QyXYw7zjIgRhUWzNxmHgME
# Faucett Brothers Activity Center        ChIJV0bo9psbhogRBT112cf3WL8
# University of Alabama                   ChIJE-c-ehioiIgRUKK8o5HtCs0
# YMCA Camp Cosby Alpine Tower            ChIJu84-g7hhiYgRsTNJ537I3LE
#
#                                            locLat    locLong  \
# Campus Recreation Center                33.500956  33.500956
# Fortenberry-Colton Fitness Center       31.324264  31.324264
# University of South Alabama - Student…  30.695525  30.695525
# High Point Climbing - Birmingham        33.420654  33.420654
# Birmingham Boulders                     33.451744  33.451744
# Gadrock                                 33.986598  33.986598
# First Avenue Rocks                      33.514665  33.514665
# High Point Climbing - Huntsville         34.73785   34.73785
# Auburn University Recreation and Well…  32.601239  32.601239
# Faucett Brothers Activity Center        33.286878  33.286878
# University of Alabama                   33.212474  33.212474
# YMCA Camp Cosby Alpine Tower            33.442905  33.442905
#
#                                            business_status  \
# Campus Recreation Center                       OPERATIONAL
# Fortenberry-Colton Fitness Center              OPERATIONAL
# University of South Alabama - Student…
# High Point Climbing - Birmingham               OPERATIONAL
# Birmingham Boulders                            OPERATIONAL
# Gadrock                                        OPERATIONAL
# First Avenue Rocks                      CLOSED_PERMANENTLY
# High Point Climbing - Huntsville               OPERATIONAL
# Auburn University Recreation and Well…         OPERATIONAL
# Faucett Brothers Activity Center               OPERATIONAL
# University of Alabama
# YMCA Camp Cosby Alpine Tower                   OPERATIONAL
#
#                                                                    google_photoReferences  \
# Campus Recreation Center                [ATtYBwLGAWXpVf9ekPrO-UEtML6Im0pdWZP56CsTxMCVD...
# Fortenberry-Colton Fitness Center       [ATtYBwK7HKyV0WzCUmYKtJw1c2-_bEEWp8jTlbUo3FFNP...
# University of South Alabama - Student…                                                 []
# High Point Climbing - Birmingham        [ATtYBwLlU6UklPCxhhf4S7ebNPfvSZtQFltLXEmh4gEn6...
# Birmingham Boulders                     [ATtYBwLijstEM4oxMPEOY7waLZhTAciYkmsau2NrvEjDD...
# Gadrock                                 [ATtYBwI957mmNRCNWXDSPmnhx4NlhKKQblGkMaFXm9-YU...
# First Avenue Rocks                      [ATtYBwKLcUGalyUqN6wSLYi2Qr7XNdelrT_JKifkFO6rz...
# High Point Climbing - Huntsville        [ATtYBwJ-yGf-wd1I0lXAmHirfCyZCls09eM2yPOxkZOaY...
# Auburn University Recreation and Well…  [ATtYBwJLuB-XnR3hPlm3XrT9KczDFPHh_LfcHGSLs9Ngj...
# Faucett Brothers Activity Center        [ATtYBwLv7pOXkwjaZmvTnsfYD9Pam76RpvKKFf2cui1Pf...
# University of Alabama                                                                  []
# YMCA Camp Cosby Alpine Tower            [ATtYBwIR-76vz-UK_23lKUcukRUCiQQjEEKOKn6Jnzm7d...
#
#                                        googleRating numUsersRated  \
# Campus Recreation Center                        4.6           343
# Fortenberry-Colton Fitness Center               4.5            52
# University of South Alabama - Student…
# High Point Climbing - Birmingham                4.7           137
# Birmingham Boulders                             4.9            74
# Gadrock                                         4.9            79
# First Avenue Rocks                              4.8            31
# High Point Climbing - Huntsville                4.7           207
# Auburn University Recreation and Well…          4.7           230
# Faucett Brothers Activity Center                4.6           125
# University of Alabama
# YMCA Camp Cosby Alpine Tower                    4.8            34
#
#                                                                                  typeList
# Campus Recreation Center                  [gym, health, point_of_interest, establishment]
# Fortenberry-Colton Fitness Center         [gym, health, point_of_interest, establishment]
# University of South Alabama - Student…                                   [street_address]
# High Point Climbing - Birmingham          [gym, health, point_of_interest, establishment]
# Birmingham Boulders                     [school, gym, health, point_of_interest, estab...
# Gadrock                                                [point_of_interest, establishment]
# First Avenue Rocks                      [school, gym, health, point_of_interest, store...
# High Point Climbing - Huntsville          [gym, health, point_of_interest, establishment]
# Auburn University Recreation and Well…    [gym, health, point_of_interest, establishment]
# Faucett Brothers Activity Center          [gym, health, point_of_interest, establishment]
# University of Alabama                                                           [premise]
# YMCA Camp Cosby Alpine Tower                           [point_of_interest, establishment]

# %%
#create table for imgs
photo_df = df[['locName', 'img_list', 'google_photoReferences']]

#remove rows without pictures
nonEmptyMask = (photo_df.img_list.astype(bool) | photo_df.google_photoReferences.astype(bool))
photo_df = photo_df[nonEmptyMask]
# Out:
#                                                                                   locName  \
# Campus Recreation Center                                            UAB Campus Recreation
# Fortenberry-Colton Fitness Center              Fortenberry-Colton Physical Fitness Center
# High Point Climbing - Birmingham             High Point Climbing and Fitness - Birmingham
# Birmingham Boulders                                                   Birmingham Boulders
# Gadrock                                                                           Gadrock
# First Avenue Rocks                                                     First Avenue Rocks
# High Point Climbing - Huntsville             High Point Climbing and Fitness - Huntsville
# Auburn University Recreation and Well…  Auburn University Campus Recreation and Wellne...
# Faucett Brothers Activity Center                         Faucett Brothers Activity Center
# YMCA Camp Cosby Alpine Tower                                              YMCA Camp Cosby
#
#                                                                                  img_list  \
# Campus Recreation Center                                                               []
# Fortenberry-Colton Fitness Center                                                      []
# High Point Climbing - Birmingham                                                       []
# Birmingham Boulders                     [https://cdn2.apstatic.com/photos/climb/119942...
# Gadrock                                                                                []
# First Avenue Rocks                                                                     []
# High Point Climbing - Huntsville        [https://cdn2.apstatic.com/photos/climb/118309...
# Auburn University Recreation and Well…                                                 []
# Faucett Brothers Activity Center                                                       []
# YMCA Camp Cosby Alpine Tower                                                           []
#
#                                                                    google_photoReferences
# Campus Recreation Center                [ATtYBwLGAWXpVf9ekPrO-UEtML6Im0pdWZP56CsTxMCVD...
# Fortenberry-Colton Fitness Center       [ATtYBwK7HKyV0WzCUmYKtJw1c2-_bEEWp8jTlbUo3FFNP...
# High Point Climbing - Birmingham        [ATtYBwLlU6UklPCxhhf4S7ebNPfvSZtQFltLXEmh4gEn6...
# Birmingham Boulders                     [ATtYBwLijstEM4oxMPEOY7waLZhTAciYkmsau2NrvEjDD...
# Gadrock                                 [ATtYBwI957mmNRCNWXDSPmnhx4NlhKKQblGkMaFXm9-YU...
# First Avenue Rocks                      [ATtYBwKLcUGalyUqN6wSLYi2Qr7XNdelrT_JKifkFO6rz...
# High Point Climbing - Huntsville        [ATtYBwJ-yGf-wd1I0lXAmHirfCyZCls09eM2yPOxkZOaY...
# Auburn University Recreation and Well…  [ATtYBwJLuB-XnR3hPlm3XrT9KczDFPHh_LfcHGSLs9Ngj...
# Faucett Brothers Activity Center        [ATtYBwLv7pOXkwjaZmvTnsfYD9Pam76RpvKKFf2cui1Pf...
# YMCA Camp Cosby Alpine Tower            [ATtYBwIR-76vz-UK_23lKUcukRUCiQQjEEKOKn6Jnzm7d...

# %%
#create table with geographical information
geo_df = df[['locName', 'locLat', 'locLong', 'gym_address']]
geo_df
# Out:
#                                                                                   locName  \
# Campus Recreation Center                                            UAB Campus Recreation
# Fortenberry-Colton Fitness Center              Fortenberry-Colton Physical Fitness Center
# University of South Alabama - Student…                              307 N University Blvd
# High Point Climbing - Birmingham             High Point Climbing and Fitness - Birmingham
# Birmingham Boulders                                                   Birmingham Boulders
# Gadrock                                                                           Gadrock
# First Avenue Rocks                                                     First Avenue Rocks
# High Point Climbing - Huntsville             High Point Climbing and Fitness - Huntsville
# Auburn University Recreation and Well…  Auburn University Campus Recreation and Wellne...
# Faucett Brothers Activity Center                         Faucett Brothers Activity Center
# University of Alabama                                           Student Recreation Center
# YMCA Camp Cosby Alpine Tower                                              YMCA Camp Cosby
#
#                                            locLat    locLong  \
# Campus Recreation Center                33.500956  33.500956
# Fortenberry-Colton Fitness Center       31.324264  31.324264
# University of South Alabama - Student…  30.695525  30.695525
# High Point Climbing - Birmingham        33.420654  33.420654
# Birmingham Boulders                     33.451744  33.451744
# Gadrock                                 33.986598  33.986598
# First Avenue Rocks                      33.514665  33.514665
# High Point Climbing - Huntsville         34.73785   34.73785
# Auburn University Recreation and Well…  32.601239  32.601239
# Faucett Brothers Activity Center        33.286878  33.286878
# University of Alabama                   33.212474  33.212474
# YMCA Camp Cosby Alpine Tower            33.442905  33.442905
#
#                                                                               gym_address
# Campus Recreation Center                 University of Alabama at Birmingham, 1501 Uni...
# Fortenberry-Colton Fitness Center        Bldg. 5900 on the corner of Skychief Street a...
# University of South Alabama - Student…   307 N University Blvd, Mobile, Alabama 36688-...
# High Point Climbing - Birmingham                       4766 US-280, Birmingham, AL 35242
# Birmingham Boulders                            136 INDUSTRIAL DRIVE BIRMINGHAM, AL 35211
# Gadrock                                  1403 Rainbow Drive Gadsden AL United States 3...
# First Avenue Rocks                       2417 1st Avenue South, Birmingham, Alabama 35...
# High Point Climbing - Huntsville         1020 Nunnahsae Park Dr. NW (4.43 mi) Huntsvil...
# Auburn University Recreation and Well…                  601 Heisman Dr, Auburn, AL 36849
# Faucett Brothers Activity Center         13040 Eugenia Faucett Drive Northport, AL 35473
# University of Alabama                        401 5th Ave East, Tuscaloosa, Alabama 35487
# YMCA Camp Cosby Alpine Tower             2290 Paul Bear Bryant Rd, Alpine, Alabama 35014

# %%
#create table with business info
business_df = df[['locName', 'google_Place_ID', "business_status", "typeList", "googleRating","numUsersRated"]]

#add columns to add info
business_df['phoneNumber'] = ""
business_df['adr_address'] = ""


business_df
# Out:
# <ipython-input-36-d190a790e42d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   business_df['phoneNumber'] = ""
# <ipython-input-36-d190a790e42d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   business_df['adr_address'] = ""
#                                                              locName  \
# Birmingham Boulders                              Birmingham Boulders
# Campus Recreation Center                    Campus Recreation Center
# Faucett Brothers Activity Center    Faucett Brothers Activity Center
# First Avenue Rocks                                First Avenue Rocks
# Fortenberry-Colton Fitness Center  Fortenberry-Colton Fitness Center
# ...                                                              ...
# Elemental Training Center                  Elemental Training Center
# Fall Hall                                                  Fall Hall
# Gottsche Glyphs                                      Gottsche Glyphs
# Pinedale Aquatic Center                      Pinedale Aquatic Center
# The Rock                                                    The Rock
#
#                                   google_Place_ID business_status typeList  \
# Birmingham Boulders
# Campus Recreation Center
# Faucett Brothers Activity Center
# First Avenue Rocks
# Fortenberry-Colton Fitness Center
# ...                                           ...             ...      ...
# Elemental Training Center
# Fall Hall
# Gottsche Glyphs
# Pinedale Aquatic Center
# The Rock
#
#                                   googleRating numUsersRated phoneNumber  \
# Birmingham Boulders
# Campus Recreation Center
# Faucett Brothers Activity Center
# First Avenue Rocks
# Fortenberry-Colton Fitness Center
# ...                                        ...           ...         ...
# Elemental Training Center
# Fall Hall
# Gottsche Glyphs
# Pinedale Aquatic Center
# The Rock
#
#                                   adr_address
# Birmingham Boulders
# Campus Recreation Center
# Faucett Brothers Activity Center
# First Avenue Rocks
# Fortenberry-Colton Fitness Center
# ...                                       ...
# Elemental Training Center
# Fall Hall
# Gottsche Glyphs
# Pinedale Aquatic Center
# The Rock
#
# [938 rows x 8 columns]

# %%
df['typeList']
# Out:
# Birmingham Boulders
# Campus Recreation Center
# Faucett Brothers Activity Center
# First Avenue Rocks
# Fortenberry-Colton Fitness Center
#                                     ..
# Elemental Training Center
# Fall Hall
# Gottsche Glyphs
# Pinedale Aquatic Center
# The Rock
# Name: typeList, Length: 938, dtype: object

# %%
define_review_df = {
    'google_Place_ID': [],
    'review_text' : [],
    'user_rating' : [],
    ''
}

review_df = pd.df(define_review_df)

# %%
fields = [
        "place_id",
        "business_status",
        "rating",
        "types",
        "user_ratings_total",
        "name",
        "geometry",
        'photos'
    ]


param={
    'key': GKEY,
    'query':'Fortenberry-Colton Fitness Center' + ' Bldg. 5900 on the corner of Skychief Street and 5th Avenue, Fort Rucker,Alabama 36362 ',
    'fields':fields
}

results = requests.get(placeTextSearchURL, params=param)

# %%
rjson = results.json()
print(json.dumps(rjson, indent=4))
# Out:
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
